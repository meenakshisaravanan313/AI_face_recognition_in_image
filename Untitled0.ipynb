# %% [markdown]
# <a href="https://colab.research.google.com/github/meenakshisaravanan313/void-mani/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
image_path = "/Aishwarya.jpg"
im = cv2.imread(image_path)
plt.imshow(im)
plt.show()
faces, confidences = cv.detect_face(im)
for face in faces:
        (startX,startY) = face[0],face[1]
        (endX,endY)     = face[2],face[3]
        cv2.rectangle(im, (startX,startY), (endX,endY), (0,255,0), 2)
        plt.imshow(im)
        plt.show()

# %%
# !pip3 install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.0MB 4.4MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.3-cp36-none-any.whl size=10043491 sha256=8bfc3b874a1b020ab8454a495b891a0078cde2677e66bb0acd90686246a8e69a
#   Stored in directory: /root/.cache/pip/wheels/c9/83/ca/701a48deacbc78758f33173252feb97297316c40af783264e2
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12073 sha256=411523a895114d2bd84951e85788c8a0eb1ab09ed6b74d8b60627f5c6c8caced
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...
